# %% [markdown]
# <a href="https://colab.research.google.com/github/amimisra/ML_Coding/blob/main/Conda_env.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing Conda to Google Collab
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# Verifying Conda Installation
# !conda --version
# Out:
# conda 23.11.0

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# prompt: install pandas numpy and matplotlib package

# !conda install pandas numpy matplotlib -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.12            |       h4ab18f5_0         543 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     ca-certificates-2024.7.4   |       hbcca054_0         151 KB  conda-forge
# ...

# %%
# prompt: check installed package in this environment

# !conda list
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# alsa-lib                  1.2.12               h4ab18f5_0    conda-forge
# archspec                  0.2.2              pyhd8ed1ab_0    conda-forge
# attr                      2.5.1                h166bdaf_1    conda-forge
# boltons                   23.1.1             pyhd8ed1ab_0    conda-forge
# brotli                    1.1.0                hd590300_1    conda-forge
# brotli-bin                1.1.0                hd590300_1    conda-forge
# brotli-python             1.1.0           py310hc6cd4ac_1    conda-forge
# bzip2                     1.0.8                hd590300_5    conda-forge
# c-ares                    1.24.0               hd590300_0    conda-forge
# ...
